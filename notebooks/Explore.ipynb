# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Special economic zones
# `worldbank.org-sez-1.1.1` Last Update: 2021-07-09T23:04:50
#
# _Information on special economic zones have been individually collected and researched in a study focusing on the governance of SEZ. This is just a subset (586) of the extant global SEZs, which have been estimated at 3500-4000._
#
#
# ## Documentation Links
#
# * [Dataset webpage](https://datacatalog.worldbank.org/dataset/special-economic-zones-sez)
# * [Dataset viewer web application](http://devseed.com/sez-viewer/#/BGD6)
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [sez](https://development-data-hub-s3-public.s3.amazonaws.com/ddhfiles/1189121/ciip_sez_ntl_2017.geojson)**. Special Economic Zones

# %%
sez = pkg.resource('sez').dataframe()
sez.head()
# Out:
#    id unique_id Check   latitude  longitude country_code  \
# 0   0     URY12   URY -33.887443 -58.416899          URY
# 1   1      URY2   URY -34.470636 -57.831424          URY
# 2   2      COL2   COL  10.960451 -74.762902          COL
# 3   3      GUY3   GUY   6.791794 -58.167016          GUY
# 4   4    IND186   IND  23.034146  70.127156          IND
#
#          country_type_combo region   country              zone_type  ...  \
# 0              URYFree Zone    LAC   Uruguay              Free Zone  ...
# 1              URYFree Zone    LAC   Uruguay              Free Zone  ...
# 2   COLFree Industrial Zone    LAC  Colombia   Free Industrial Zone  ...
# 3      GUYIndustrial Estate    LAC    Guyana      Industrial Estate  ...
# 4  INDSpecial Economic Zone     SA     India  Special Economic Zone  ...
#
#   populous_citydist                                            city_1m  \
# 0               265                                         Montevideo
# 1               182                                         Montevideo
# 2              1013                                       Barranquilla
# 3                 4  No city in country with population greater tha...
# 4               830                                             Rajkot
#
#   city_1mdist                                          city_500k  \
# 0         265                                         Montevideo
# 1         182                                         Montevideo
# 2           6                                       Barranquilla
# 3           0  No city in country with population greater tha...
# 4         191                                              Morbi
#
#   city_500kdist   500kcity_range  \
# 0           265     50 to 299 km
# 1           182     50 to 299 km
# 2             6  Less than 50 km
# 3             0  Less than 50 km
# 4           191     50 to 299 km
#
#                                            city_300k city_300kdist  \
# 0                                         Montevideo           265
# 1                                         Montevideo           182
# 2                                       Barranquilla             6
# 3  No city in country with population greater tha...             0
# 4                                              Morbi           191
#
#                                                 Note  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  The Government has noted that existing industr...
# 4                                               None
#
#                         geometry
# 0  POINT (-58.416899 -33.887443)
# 1  POINT (-57.831424 -34.470636)
# 2   POINT (-74.762902 10.960451)
# 3    POINT (-58.167016 6.791794)
# 4    POINT (70.127156 23.034146)
#
# [5 rows x 62 columns]

# %%
sez.country.value_counts()
# Out:
# Vietnam               94
# Korea                 86
# Turkey                53
# Philippines           47
# China                 35
# Indonesia             27
# Thailand              26
# Colombia              22
# Dominican Republic    14
# Russia                13
# Sri Lanka             13
# Bangladesh            11
# Uruguay               10
# Ethiopia               9
# Costa Rica             9
# India                  9
# Honduras               8
# Egypt                  8
# Nigeria                8
# Argentina              7
# Cameroon               6
# Tanzania               6
# Bolivia                6
# Mozambique             4
# Pakistan               4
# Malaysia               4
# Jordan                 4
# Haiti                  3
# Chile                  3
# Jamaica                3
# Guyana                 3
# Belize                 2
# South Africa           2
# Eritrea                2
# Lesotho                2
# Senegal                2
# Guatemala              2
# Djibouti               2
# Ghana                  1
# Sudan                  1
# Cote D'Ivoire          1
# Kenya                  1
# Gambia                 1
# Fiji                   1
# Benin                  1
# Rwanda                 1
# Angola                 1
# Republic of Congo      1
# Uganda                 1
# Madagascar             1
# Zimbabwe               1
# Burundi                1
# Botswana               1
# Name: country, dtype: int64
